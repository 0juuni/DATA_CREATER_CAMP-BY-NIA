# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/데이터 크리에이터 캠프/Data/Data_2(라벨별_분류).zip'
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: content/Data_2(라벨별_분류)/bottoms/img28802.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img8052.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img27927.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img13671.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img19845.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img22978.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img22452.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img6804.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img28068.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img17842.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img19143.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img20855.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img17688.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img4737.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img13015.jpg
#   inflating: content/Data_2(라벨별_분류)/bottoms/img7673.jpg
# ...

# %%
# 잘 압축이 풀어졌는지 확인
import os

bottoms_cnt = len(os.listdir("/content/content/Data_2(라벨별_분류)/bottoms"))
capandhat_cnt = len(os.listdir("/content/content/Data_2(라벨별_분류)/cap_and_hat"))
outerwear_cnt = len(os.listdir("/content/content/Data_2(라벨별_분류)/outerwear"))
shoes_cnt = len(os.listdir("/content/content/Data_2(라벨별_분류)/shoes"))
tops_cnt = len(os.listdir("/content/content/Data_2(라벨별_분류)/tops"))

print('bottoms_cnt :', bottoms_cnt)
print('cap_and_hat :', capandhat_cnt)
print('outerwear : ', outerwear_cnt)
print('shoes_cnt :', shoes_cnt)
print('tops_cnt :', tops_cnt)
print('All :', bottoms_cnt + capandhat_cnt + outerwear_cnt + shoes_cnt + tops_cnt)
# Out:
# bottoms_cnt : 6424
# cap_and_hat : 196
# outerwear :  4606
# shoes_cnt : 424
# tops_cnt : 18350
# All : 30000

# %%
# !pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import splitfolders
splitfolders.ratio("/content/content/Data_2(라벨별_분류)", output ="/content/train_test", seed = 42, ratio=(.8,.2))
# Out:
# Copying files: 30000 files [01:42, 293.81 files/s]

# %%
# !mv '/content/train_test/val' '/content/train_test/test'

# %%
train_bottoms_cnt = len(os.listdir("/content/train_test/train/bottoms"))
train_capandhat_cnt = len(os.listdir("/content/train_test/train/cap_and_hat"))
train_outerwear_cnt = len(os.listdir("/content/train_test/train/outerwear"))
train_shoes_cnt = len(os.listdir("/content/train_test/train/shoes"))
train_tops_cnt = len(os.listdir("/content/train_test/train/tops"))
print('train_데이터 수 : ', train_bottoms_cnt + train_capandhat_cnt + train_outerwear_cnt + train_shoes_cnt + train_tops_cnt )

test_bottoms_cnt = len(os.listdir("/content/train_test/test/bottoms"))
test_capandhat_cnt = len(os.listdir("/content/train_test/test/cap_and_hat"))
test_outerwear_cnt = len(os.listdir("/content/train_test/test/outerwear"))
test_shoes_cnt = len(os.listdir("/content/train_test/test/shoes"))
test_tops_cnt = len(os.listdir("/content/train_test/test/tops"))
print('test_데이터 수 : ', test_bottoms_cnt + test_capandhat_cnt + test_outerwear_cnt + test_shoes_cnt + test_tops_cnt )
# Out:
# train_데이터 수 :  23998
# test_데이터 수 :  6002

# %%
# !zip -r '/content/drive/MyDrive/대회/데이터 크리에이터 캠프/Data/Data_3(테스트_트레인_분류).zip' '/content/train_test'
